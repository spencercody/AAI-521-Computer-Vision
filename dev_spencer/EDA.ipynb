# %% [markdown]
# # EDA

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import matplotlib.pyplot as plt
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib._api import MatplotlibDeprecationWarning
#     163 from matplotlib.rcsetup import cycler  # noqa: F401
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\matplotlib\rcsetup.py:28
#      26 from matplotlib.backends import BackendFilter, backend_registry
#      27 from matplotlib.cbook import ls_mapper
# ---> 28 from matplotlib.colors import Colormap, is_color_like
#      29 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      30 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\matplotlib\colors.py:57
#      55 import matplotlib as mpl
#      56 import numpy as np
# ---> 57 from matplotlib import _api, _cm, cbook, scale, _image
#      58 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      61 class _ColorMapping(dict):
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\matplotlib\scale.py:764
#     755         docs.extend([
#     756             f"    {name!r}",
#     757             "",
#     758             textwrap.indent(docstring, " " * 8),
#     759             ""
#     760         ])
#     761     return "\n".join(docs)
# --> 764 _docstring.interpd.register(
#     765     scale_type='{%s}' % ', '.join([repr(x) for x in get_scale_names()]),
#     766     scale_docs=_get_scale_docs().rstrip(),
#     767     )
#
# AttributeError: '_ArtistPropertiesSubstitution' object has no attribute 'register'

# %%
# Install dependencies as needed:
# pip install kagglehub[pandas-datasets]
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "labels.csv"

# Load the latest version
df = kagglehub.dataset_load(
  KaggleDatasetAdapter.PANDAS,
  "fmena14/crowd-counting",
  file_path,
)

print("First 5 records:", df.head())
# Out:
# First 5 records:    id  count
# 0   1     35
# 1   2     41
# 2   3     41
# 3   4     44
# 4   5     41

# %%
df['count'].describe().round(1)
# Out:
# count    2000.0
# mean       31.2
# std         6.9
# min        13.0
# 25%        26.0
# 50%        31.0
# 75%        36.0
# max        53.0
# Name: count, dtype: float64

# %%
import numpy as np

# %%
loaded_frames = np.load('../data/images.npy')

# %%
file_path = "frames"

imgs = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "fmena14/crowd-counting",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)
# Out:
# C:\Users\speco\AppData\Local\Temp\ipykernel_11112\3188408827.py:3: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   imgs = kagglehub.load_dataset(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 file_path = "frames"
# ----> 3 imgs = kagglehub.load_dataset(
#       4   KaggleDatasetAdapter.PANDAS,
#       5   "fmena14/crowd-counting",
#       6   file_path,
#       7   # Provide any additional arguments like
#       8   # sql_query or pandas_kwargs. See the
#       9   # documenation for more information:
#      10   # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
#      11 )
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\kagglehub\datasets.py:178, in load_dataset(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs)
#     163 def load_dataset(
#     164     adapter: KaggleDatasetAdapter,
#     165     # In the form of {owner_slug}/{dataset_slug} or {owner_slug}/{dataset_slug}/versions/{version_number}
#    (...)    171     hf_kwargs: Any = None,  # noqa: ANN401
#     172 ) -> Any:  # noqa: ANN401
#     173     warnings.warn(
#     174         "Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.",
#     175         DeprecationWarning,
#     176         stacklevel=2,
#     177     )
# --> 178     return dataset_load(adapter, handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query, hf_kwargs=hf_kwargs)
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\kagglehub\datasets.py:141, in dataset_load(adapter, handle, path, pandas_kwargs, sql_query, hf_kwargs, polars_frame_type, polars_kwargs)
#     138 elif adapter is KaggleDatasetAdapter.PANDAS:
#     139     import kagglehub.pandas_datasets  # noqa: PLC0415
# --> 141     return kagglehub.pandas_datasets.load_pandas_dataset(
#     142         handle, path, pandas_kwargs=pandas_kwargs, sql_query=sql_query
#     143     )
#     144 elif adapter is KaggleDatasetAdapter.POLARS:
#     145     import kagglehub.polars_datasets  # noqa: PLC0415
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\kagglehub\pandas_datasets.py:86, in load_pandas_dataset(handle, path, pandas_kwargs, sql_query)
#      84 pandas_kwargs = {} if pandas_kwargs is None else pandas_kwargs
#      85 file_extension = os.path.splitext(path)[1]
# ---> 86 read_function = _validate_read_function(file_extension, sql_query)
#      88 # Now that everything has been validated, we can start downloading and processing
#      89 filepath = dataset_download(handle, path)
#
# File ~\anaconda3\envs\computer_vision\Lib\site-packages\kagglehub\pandas_datasets.py:108, in _validate_read_function(file_extension, sql_query)
#     103 if file_extension not in SUPPORTED_READ_FUNCTIONS_BY_EXTENSION:
#     104     extension_error_message = (
#     105         f"Unsupported file extension: '{file_extension}'. "
#     106         f"Supported file extensions are: {', '.join(SUPPORTED_READ_FUNCTIONS_BY_EXTENSION.keys())}"
#     107     )
# --> 108     raise ValueError(extension_error_message) from None
#     110 read_function = SUPPORTED_READ_FUNCTIONS_BY_EXTENSION[file_extension]
#     111 if read_function is wrapped_read_sql_query and not sql_query:
#
# ValueError: Unsupported file extension: ''. Supported file extensions are: .csv, .tsv, .json, .jsonl, .xml, .parquet, .feather, .sqlite, .sqlite3, .db, .db3, .s3db, .dl3, .xls, .xlsx, .xlsm, .xlsb, .odf, .ods, .odt
