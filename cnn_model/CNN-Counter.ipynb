# %%
from pathlib import Path
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import keras
from keras import layers
import numpy as np
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model

# %% [markdown]
# ## Data Set Up

# %%
import kagglehub

# Download latest version
download_path = kagglehub.dataset_download("fmena14/crowd-counting")

print("Path to dataset files:", download_path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/fmena14/crowd-counting?dataset_version_number=3...
# 100%|██████████| 1.18G/1.18G [00:09<00:00, 133MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fmena14/crowd-counting/versions/3

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# local
data_folder = Path('../data')
# g-drive
data_folder = Path('/content/drive/MyDrive/Colab Notebooks/USD/6_computer_vision/AAI-521-Computer-Vision/data')
# local colab
data_folder = Path(download_path)
label_path = data_folder / 'labels.csv'
imgs_folder = data_folder / 'frames' /'frames'

# %%
df = pd.read_csv(label_path)

# %%
df.head(2)
# Out:
#    id  count
# 0   1     35
# 1   2     41

# %% [markdown]
# ##### adding full img path column

# %%
def get_img_filename(image_id: int)-> Path:
    image_id = str(image_id).rjust(6, '0')
    img_name = f'seq_{image_id}.jpg'
    return img_name

# %%
def get_img_path(image_id: int, image_folder: Path)-> Path:
    image_id = str(image_id).rjust(6, '0')
    img_name = f'seq_{image_id}.jpg'
    img_path = image_folder / img_name
    return img_path

# %%
df['img_file_name'] = df.id.apply(lambda x: get_img_filename(x))

# %%
df.head(3)
# Out:
#    id  count   img_file_name
# 0   1     35  seq_000001.jpg
# 1   2     41  seq_000002.jpg
# 2   3     41  seq_000003.jpg

# %% [markdown]
# #### splitting into train, test, and validation

# %%
train_val_df, test_df = train_test_split(df,
                                     test_size=0.2,
                                     random_state=88,
                                     #stratify=df['count']
                                    )

train_df, val_df = train_test_split(train_val_df,
                                    test_size=0.25,
                                    random_state=42,
                                    )

train_df = train_df.reset_index(drop=True)
test_df = test_df.reset_index(drop=True)
val_df = val_df.reset_index(drop=True)

# %%
len(test_df)
# Out:
# 400

# %%
len(train_df)
# Out:
# 1200

# %%
len(val_df)
# Out:
# 400

# %% [markdown]
# #### augmentation

# %%
train_datagen = ImageDataGenerator(
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    rescale=1./255 # Normalize pixel values
)
#val_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %%
IMAGE_SIZE = (128, 128)
BATCH_SIZE = 32

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory=imgs_folder,
    x_col='img_file_name',
    y_col='count',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='raw'
)
# Out:
# Found 1200 validated image filenames.

# %%
test_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    directory=imgs_folder,
    x_col='img_file_name',
    y_col='count',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='raw',
    shuffle=False
)

val_generator = test_datagen.flow_from_dataframe(
    dataframe=val_df,
    directory=imgs_folder,
    x_col='img_file_name',
    y_col='count',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='raw'
)
# Out:
# Found 400 validated image filenames.
# Found 400 validated image filenames.

# %%
def manual_img_preprocessing(img_path):
    img = load_img(img_path, target_size=IMAGE_SIZE)
    img_array = img_to_array(img) / 255.0
    img_array = np.expand_dims(img_array, axis=0) # Add batch dimension
    return img_array

# %% [markdown]
# ---

# %% [markdown]
# ### Model Layout

# %% [markdown]
# ##### configs

# %%
input_shape = (IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
kernel_size = (3, 3)
pool_size = (2, 2)

# %% [markdown]
# #### model layout

# %%
model = keras.Sequential(
    [
        keras.Input(shape=input_shape),

        layers.Conv2D(64, kernel_size=kernel_size,
                      activation='relu', padding='same', strides=2),
        layers.Conv2D(128, kernel_size=kernel_size,
                      activation='relu', padding='same'),
        layers.MaxPooling2D(pool_size=pool_size, strides=2),

        layers.Conv2D(256, kernel_size=kernel_size,
                      activation='relu', padding='same'),
        layers.MaxPooling2D(pool_size=pool_size, strides=2),

        layers.Conv2D(256, kernel_size=kernel_size,
                      activation='relu', padding='same'),
        layers.Conv2D(128, kernel_size=kernel_size,
                      activation='relu', padding='same'),
        layers.MaxPooling2D(pool_size=pool_size, strides=2),

        layers.Conv2D(64, kernel_size=kernel_size,
                      activation='relu', padding='same'),
        layers.MaxPooling2D(pool_size=pool_size, strides=2),

        layers.Dropout(.25),
        layers.Flatten(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.25),
        layers.Dense(1, activation="relu") # we can use relu bc its counts of people, therefore can't be negative
    ]
)

model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)              │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 64, 64, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_16 (MaxPooling2D) │ (None, 32, 32, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_26 (Conv2D)              │ (None, 32, 32, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_17 (MaxPooling2D) │ (None, 16, 16, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_27 (Conv2D)              │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_28 (Conv2D)              │ (None, 16, 16, 128)    │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_18 (MaxPooling2D) │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_29 (Conv2D)              │ (None, 8, 8, 64)       │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_19 (MaxPooling2D) │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 4, 4, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,855,041 (7.08 MB)
#  Trainable params: 1,855,041 (7.08 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### compile the model

# %%
l_rate = 0.0004
optimizer = keras.optimizers.Adam(learning_rate=l_rate)
model.compile(
    optimizer=optimizer,
    loss="mse",
    metrics=["mae"]
)

# %% [markdown]
# ## Training

# %%
early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=30, # 20 may be a bit too patient
        min_delta=0.001,
        mode='min',
        restore_best_weights=True
    )

# %%
import tensorflow as tf

# Check if GPU is available
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.test.is_built_with_cuda())
# Out:
# True

# %%
model.fit(
        train_generator,
        epochs=200, # Set a high number of epochs, as early stopping will manage the actual stopping point
        validation_data=val_generator,
        callbacks=[early_stopping]
    )
# Out:
# Epoch 1/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 16s 289ms/step - loss: 402.0398 - mae: 16.5379 - val_loss: 59.6470 - val_mae: 6.2062
# Epoch 2/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 58.9858 - mae: 6.1632 - val_loss: 57.6465 - val_mae: 5.9973
# Epoch 3/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 58.5071 - mae: 6.1328 - val_loss: 62.0289 - val_mae: 6.1164
# Epoch 4/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 65.5724 - mae: 6.4411 - val_loss: 58.0349 - val_mae: 6.2624
# Epoch 5/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 51.6916 - mae: 5.7178 - val_loss: 97.7629 - val_mae: 8.5087
# Epoch 6/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 50.9619 - mae: 5.6737 - val_loss: 76.3485 - val_mae: 7.4398
# Epoch 7/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 49.5696 - mae: 5.6255 - val_loss: 37.6185 - val_mae: 4.9990
# Epoch 8/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 47.1966 - mae: 5.4128 - val_loss: 55.5004 - val_mae: 6.2796
# Epoch 9/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 41.3956 - mae: 5.0168 - val_loss: 36.3096 - val_mae: 4.9819
# Epoch 10/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 32.7448 - mae: 4.4343 - val_loss: 56.0532 - val_mae: 6.3364
# Epoch 11/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 34.4734 - mae: 4.6711 - val_loss: 37.3270 - val_mae: 5.0763
# Epoch 12/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 30.6112 - mae: 4.4167 - val_loss: 84.9155 - val_mae: 8.1821
# Epoch 13/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 44.2682 - mae: 5.2115 - val_loss: 40.8810 - val_mae: 5.3351
# Epoch 14/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 29.2671 - mae: 4.3037 - val_loss: 43.2554 - val_mae: 5.5142
# Epoch 15/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 26.3130 - mae: 4.0496 - val_loss: 25.4102 - val_mae: 4.1092
# Epoch 16/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 28.3102 - mae: 4.3712 - val_loss: 35.5743 - val_mae: 4.9459
# Epoch 17/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 27.3732 - mae: 4.1627 - val_loss: 51.4544 - val_mae: 6.1574
# Epoch 18/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 29.1027 - mae: 4.2562 - val_loss: 23.7724 - val_mae: 3.9913
# Epoch 19/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 34.5363 - mae: 4.6081 - val_loss: 28.5155 - val_mae: 4.3937
# Epoch 20/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 26.5301 - mae: 4.1311 - val_loss: 54.6690 - val_mae: 6.4698
# Epoch 21/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 25.2526 - mae: 3.9983 - val_loss: 46.4198 - val_mae: 5.8519
# Epoch 22/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 24.3861 - mae: 3.9506 - val_loss: 33.7865 - val_mae: 4.8551
# Epoch 23/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 26.5726 - mae: 4.0545 - val_loss: 40.0250 - val_mae: 5.4085
# Epoch 24/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 25.3005 - mae: 4.0692 - val_loss: 97.9915 - val_mae: 9.1411
# Epoch 25/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 28.8178 - mae: 4.2586 - val_loss: 17.3502 - val_mae: 3.3705
# Epoch 26/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 31.4782 - mae: 4.4696 - val_loss: 50.7459 - val_mae: 6.1879
# Epoch 27/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 23.4228 - mae: 3.8781 - val_loss: 17.1666 - val_mae: 3.3376
# Epoch 28/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 27.6685 - mae: 4.2154 - val_loss: 19.3287 - val_mae: 3.5875
# Epoch 29/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 23.1386 - mae: 3.8645 - val_loss: 149.9629 - val_mae: 11.6562
# Epoch 30/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 31.8298 - mae: 4.6052 - val_loss: 31.2778 - val_mae: 4.6993
# Epoch 31/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 24.8852 - mae: 3.9589 - val_loss: 41.0956 - val_mae: 5.5242
# Epoch 32/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 21.1389 - mae: 3.6354 - val_loss: 17.2380 - val_mae: 3.3009
# Epoch 33/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 22.1714 - mae: 3.7536 - val_loss: 112.1373 - val_mae: 9.9616
# Epoch 34/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 25.0233 - mae: 3.9603 - val_loss: 25.4372 - val_mae: 4.1560
# Epoch 35/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 21.5844 - mae: 3.7473 - val_loss: 61.1702 - val_mae: 7.0505
# Epoch 36/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 187ms/step - loss: 22.4467 - mae: 3.7357 - val_loss: 44.9103 - val_mae: 5.8577
# Epoch 37/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 22.0231 - mae: 3.7228 - val_loss: 19.8124 - val_mae: 3.6117
# Epoch 38/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 20.4050 - mae: 3.5918 - val_loss: 48.6611 - val_mae: 6.1665
# Epoch 39/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 20.4385 - mae: 3.6085 - val_loss: 12.8649 - val_mae: 2.8386
# Epoch 40/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 18.6849 - mae: 3.4696 - val_loss: 24.7969 - val_mae: 4.1446
# Epoch 41/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 21.2317 - mae: 3.6798 - val_loss: 38.5830 - val_mae: 5.3967
# Epoch 42/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 19.3624 - mae: 3.5143 - val_loss: 43.0702 - val_mae: 5.7765
# Epoch 43/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 17.0829 - mae: 3.3036 - val_loss: 36.6505 - val_mae: 5.2141
# Epoch 44/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 15.8544 - mae: 3.2023 - val_loss: 68.3508 - val_mae: 7.6597
# Epoch 45/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 18.6669 - mae: 3.3855 - val_loss: 40.1761 - val_mae: 5.5769
# Epoch 46/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 18.7962 - mae: 3.3708 - val_loss: 16.1473 - val_mae: 3.2647
# Epoch 47/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 15.4755 - mae: 3.0767 - val_loss: 45.3391 - val_mae: 6.0574
# Epoch 48/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 17.5497 - mae: 3.3373 - val_loss: 18.4637 - val_mae: 3.5549
# Epoch 49/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 17.6934 - mae: 3.3354 - val_loss: 73.1905 - val_mae: 7.9565
# Epoch 50/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 14.3361 - mae: 3.0083 - val_loss: 10.1562 - val_mae: 2.5576
# Epoch 51/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 14.4971 - mae: 2.9563 - val_loss: 18.8019 - val_mae: 3.6303
# Epoch 52/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 15.1662 - mae: 3.0858 - val_loss: 9.0203 - val_mae: 2.4183
# Epoch 53/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 16.9597 - mae: 3.2590 - val_loss: 21.3705 - val_mae: 3.9454
# Epoch 54/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 13.3183 - mae: 2.9009 - val_loss: 50.8741 - val_mae: 6.5475
# Epoch 55/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 13.3793 - mae: 2.8969 - val_loss: 9.2585 - val_mae: 2.4858
# Epoch 56/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 15.1876 - mae: 3.0754 - val_loss: 42.5195 - val_mae: 5.9179
# Epoch 57/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 14.3582 - mae: 2.9670 - val_loss: 8.0232 - val_mae: 2.2936
# Epoch 58/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 13.4557 - mae: 2.9110 - val_loss: 35.3125 - val_mae: 5.2632
# Epoch 59/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 12.0082 - mae: 2.7051 - val_loss: 22.3118 - val_mae: 4.0559
# Epoch 60/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 15.5753 - mae: 3.1615 - val_loss: 29.8717 - val_mae: 4.8112
# Epoch 61/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 12.2936 - mae: 2.7458 - val_loss: 55.0582 - val_mae: 6.8743
# Epoch 62/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 18.2143 - mae: 3.4138 - val_loss: 11.1663 - val_mae: 2.7505
# Epoch 63/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 14.7415 - mae: 3.1162 - val_loss: 8.9445 - val_mae: 2.4364
# Epoch 64/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 12.0735 - mae: 2.7864 - val_loss: 14.8919 - val_mae: 3.2358
# Epoch 65/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 11.4720 - mae: 2.6888 - val_loss: 11.1817 - val_mae: 2.7442
# Epoch 66/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 12.5821 - mae: 2.8183 - val_loss: 10.8409 - val_mae: 2.6412
# Epoch 67/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 15.6818 - mae: 3.2251 - val_loss: 32.7392 - val_mae: 5.0737
# Epoch 68/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 12.2485 - mae: 2.7754 - val_loss: 13.3658 - val_mae: 3.0281
# Epoch 69/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 11.4680 - mae: 2.6434 - val_loss: 13.6943 - val_mae: 3.1015
# Epoch 70/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 11.4938 - mae: 2.6504 - val_loss: 36.5429 - val_mae: 5.4922
# Epoch 71/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 11.4523 - mae: 2.7257 - val_loss: 6.8608 - val_mae: 2.0965
# Epoch 72/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 13.6852 - mae: 2.9375 - val_loss: 12.1317 - val_mae: 2.9153
# Epoch 73/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 11.1583 - mae: 2.6674 - val_loss: 31.7128 - val_mae: 5.0735
# Epoch 74/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 12.0385 - mae: 2.7230 - val_loss: 38.3146 - val_mae: 5.5103
# Epoch 75/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 14.8979 - mae: 3.1015 - val_loss: 15.0651 - val_mae: 3.2923
# Epoch 76/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 11.1793 - mae: 2.6289 - val_loss: 11.9581 - val_mae: 2.8559
# Epoch 77/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 12.5636 - mae: 2.7987 - val_loss: 12.1506 - val_mae: 2.9334
# Epoch 78/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 9.6965 - mae: 2.4357 - val_loss: 7.0514 - val_mae: 2.1609
# Epoch 79/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 11.2049 - mae: 2.6057 - val_loss: 25.6991 - val_mae: 4.5369
# Epoch 80/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 13.2781 - mae: 2.8928 - val_loss: 11.9119 - val_mae: 2.8123
# Epoch 81/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 10.5647 - mae: 2.5572 - val_loss: 10.6565 - val_mae: 2.7281
# Epoch 82/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 9.5243 - mae: 2.4252 - val_loss: 10.7644 - val_mae: 2.6918
# Epoch 83/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 9.9660 - mae: 2.5232 - val_loss: 29.0755 - val_mae: 4.8807
# Epoch 84/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 13.1359 - mae: 2.8908 - val_loss: 5.5988 - val_mae: 1.8987
# Epoch 85/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 9.3225 - mae: 2.4101 - val_loss: 16.8015 - val_mae: 3.5411
# Epoch 86/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 11.0069 - mae: 2.6677 - val_loss: 6.1886 - val_mae: 1.9742
# Epoch 87/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 9.8994 - mae: 2.4795 - val_loss: 7.3694 - val_mae: 2.1793
# Epoch 88/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 9.6078 - mae: 2.4397 - val_loss: 7.1396 - val_mae: 2.1651
# Epoch 89/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 10.2719 - mae: 2.5034 - val_loss: 10.1596 - val_mae: 2.5927
# Epoch 90/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 9.5927 - mae: 2.4444 - val_loss: 25.4321 - val_mae: 4.5824
# Epoch 91/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 11.4073 - mae: 2.6995 - val_loss: 12.5766 - val_mae: 2.9289
# Epoch 92/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 9.1731 - mae: 2.3798 - val_loss: 17.2649 - val_mae: 3.5582
# Epoch 93/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 9.5508 - mae: 2.4511 - val_loss: 14.1378 - val_mae: 3.2294
# Epoch 94/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 8.7341 - mae: 2.3268 - val_loss: 10.3734 - val_mae: 2.6803
# Epoch 95/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 9.4304 - mae: 2.4442 - val_loss: 9.3063 - val_mae: 2.5479
# Epoch 96/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 8.6367 - mae: 2.3770 - val_loss: 12.4760 - val_mae: 2.9172
# Epoch 97/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 8.3327 - mae: 2.3118 - val_loss: 6.1472 - val_mae: 2.0319
# Epoch 98/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 10.7043 - mae: 2.6138 - val_loss: 5.9212 - val_mae: 1.8688
# Epoch 99/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 9.1962 - mae: 2.3684 - val_loss: 4.8991 - val_mae: 1.7331
# Epoch 100/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 9.9780 - mae: 2.5052 - val_loss: 8.0369 - val_mae: 2.3659
# Epoch 101/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 9.8735 - mae: 2.4694 - val_loss: 5.7851 - val_mae: 1.9374
# Epoch 102/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 7.3412 - mae: 2.1858 - val_loss: 23.6014 - val_mae: 4.3088
# Epoch 103/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 8.8442 - mae: 2.3480 - val_loss: 18.7859 - val_mae: 3.7005
# Epoch 104/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 9.0240 - mae: 2.3872 - val_loss: 8.0968 - val_mae: 2.3496
# Epoch 105/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 10.7250 - mae: 2.5950 - val_loss: 11.6848 - val_mae: 2.8898
# Epoch 106/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 9.3789 - mae: 2.4200 - val_loss: 21.9108 - val_mae: 4.2104
# Epoch 107/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 7.9755 - mae: 2.2747 - val_loss: 6.3110 - val_mae: 2.0141
# Epoch 108/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 9.5027 - mae: 2.4390 - val_loss: 11.8276 - val_mae: 2.9348
# Epoch 109/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 7.8127 - mae: 2.1902 - val_loss: 4.8506 - val_mae: 1.7439
# Epoch 110/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 9.4875 - mae: 2.4575 - val_loss: 5.0937 - val_mae: 1.8290
# Epoch 111/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 11.8104 - mae: 2.7087 - val_loss: 9.4717 - val_mae: 2.5330
# Epoch 112/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 189ms/step - loss: 11.2386 - mae: 2.6908 - val_loss: 5.5703 - val_mae: 1.8390
# Epoch 113/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 11.1169 - mae: 2.6223 - val_loss: 5.7828 - val_mae: 1.9177
# Epoch 114/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 8.3426 - mae: 2.2938 - val_loss: 13.7121 - val_mae: 3.0721
# Epoch 115/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 7.1529 - mae: 2.1274 - val_loss: 4.7847 - val_mae: 1.7532
# Epoch 116/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 7.7003 - mae: 2.2017 - val_loss: 15.3767 - val_mae: 3.3992
# Epoch 117/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 9.3745 - mae: 2.3983 - val_loss: 4.8602 - val_mae: 1.7010
# Epoch 118/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 179ms/step - loss: 8.4312 - mae: 2.2847 - val_loss: 8.7593 - val_mae: 2.4431
# Epoch 119/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 8.1183 - mae: 2.2847 - val_loss: 11.2289 - val_mae: 2.8319
# Epoch 120/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 8.2169 - mae: 2.2659 - val_loss: 5.4360 - val_mae: 1.8768
# Epoch 121/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 7.3254 - mae: 2.0838 - val_loss: 4.5989 - val_mae: 1.6768
# Epoch 122/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 7.3857 - mae: 2.1782 - val_loss: 5.4263 - val_mae: 1.8734
# Epoch 123/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 7.8492 - mae: 2.2291 - val_loss: 4.6177 - val_mae: 1.6876
# Epoch 124/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 7.2043 - mae: 2.0895 - val_loss: 7.3472 - val_mae: 2.1970
# Epoch 125/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 7.9817 - mae: 2.2236 - val_loss: 5.3384 - val_mae: 1.8583
# Epoch 126/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 9.1877 - mae: 2.3788 - val_loss: 4.7004 - val_mae: 1.7252
# Epoch 127/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 6.2262 - mae: 1.9668 - val_loss: 10.8769 - val_mae: 2.8420
# Epoch 128/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 8.6073 - mae: 2.3356 - val_loss: 15.7032 - val_mae: 3.4359
# Epoch 129/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 8.7111 - mae: 2.3504 - val_loss: 4.7928 - val_mae: 1.7359
# Epoch 130/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 7.5586 - mae: 2.1713 - val_loss: 4.8124 - val_mae: 1.7513
# Epoch 131/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 8.1445 - mae: 2.2701 - val_loss: 4.8104 - val_mae: 1.7345
# Epoch 132/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 6.4449 - mae: 2.0031 - val_loss: 8.2718 - val_mae: 2.3747
# Epoch 133/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 7.4880 - mae: 2.1756 - val_loss: 11.0116 - val_mae: 2.8382
# Epoch 134/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 6.8624 - mae: 2.0979 - val_loss: 31.7211 - val_mae: 5.1888
# Epoch 135/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 10.3572 - mae: 2.5869 - val_loss: 15.1753 - val_mae: 3.4019
# Epoch 136/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 7.2222 - mae: 2.1340 - val_loss: 11.5762 - val_mae: 2.8637
# Epoch 137/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 7.6116 - mae: 2.1636 - val_loss: 5.8575 - val_mae: 1.9502
# Epoch 138/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 186ms/step - loss: 7.0645 - mae: 2.0917 - val_loss: 11.2247 - val_mae: 2.8468
# Epoch 139/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 7.1806 - mae: 2.1041 - val_loss: 5.0219 - val_mae: 1.7960
# Epoch 140/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 9.5995 - mae: 2.4685 - val_loss: 9.7295 - val_mae: 2.6173
# Epoch 141/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 178ms/step - loss: 7.2927 - mae: 2.1673 - val_loss: 5.3991 - val_mae: 1.7809
# Epoch 142/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 7.7284 - mae: 2.1728 - val_loss: 5.7901 - val_mae: 1.9546
# Epoch 143/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 6.5933 - mae: 2.0454 - val_loss: 4.8081 - val_mae: 1.6991
# Epoch 144/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 8.9719 - mae: 2.3631 - val_loss: 15.0387 - val_mae: 3.4110
# Epoch 145/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 185ms/step - loss: 7.1450 - mae: 2.1245 - val_loss: 5.0948 - val_mae: 1.7712
# Epoch 146/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 184ms/step - loss: 6.1457 - mae: 1.9510 - val_loss: 4.6453 - val_mae: 1.7198
# Epoch 147/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 182ms/step - loss: 6.2034 - mae: 1.9252 - val_loss: 7.3068 - val_mae: 2.2183
# Epoch 148/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 7.1410 - mae: 2.1303 - val_loss: 5.2464 - val_mae: 1.8308
# Epoch 149/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 183ms/step - loss: 7.4026 - mae: 2.1485 - val_loss: 5.1210 - val_mae: 1.7997
# Epoch 150/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - loss: 6.4998 - mae: 1.9770 - val_loss: 5.3012 - val_mae: 1.8524
# Epoch 151/200
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 7s 180ms/step - loss: 6.4181 - mae: 2.0283 - val_loss: 5.6290 - val_mae: 1.8160

# %%
model_folder = Path('/content/drive/MyDrive/Colab Notebooks/USD/6_computer_vision/AAI-521-Computer-Vision/dev_spencer/models')

# %%
# save model
model_file_name = 'cnn-counting-model-25Nov2025-0004.keras'
full_model_path = model_folder / model_file_name
model.save(full_model_path)

# %%
# load model
#model = load_model(full_model_path)

# %%
model_hist = model.history.history

# %%
import pickle
history_path = model_folder / 'cnn-counting-model-history-25Nov2025-0004.pickle'

with open(history_path, 'wb') as file_pi:
    pickle.dump(model_hist, file_pi)

# %%
train_loss = model_hist['loss']
val_loss = model_hist['val_loss']
train_mae = model_hist['mae'] # mean absolute error
val_mae = model_hist['val_mae']

# %%
# Plot training & validation loss values
plt.figure( figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(train_loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# Plot training & validation accuracy values
plt.subplot(1, 2, 2)
plt.plot(train_mae, label='Training MAE')
plt.plot(val_mae, label='Validation MAE')
plt.title('Model Mean Absolute Error (MAE)')
plt.xlabel('Epoch')
plt.ylabel('MAE')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# The oscillating loss and MAE could be indicative that the learning rate was too high on this training.

# %% [markdown]
# ## Evaluating Test Set

# %%
results = model.evaluate(
    test_generator,
    steps=test_generator.samples // BATCH_SIZE
    # steps ensures the generator covers the whole dataset exactly
)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 4.2893 - mae: 1.6390

# %%
test_loss = results[0] # This is the Mean Squared Error (MSE)
test_mae = results[1]  # This is the Mean Absolute Error (MAE)

# %%
print(f'Loss for the test dataset = {round(test_loss, 3)}')
print(f'Mean Absolute Error for the test dataset = {round(test_mae,3)}')
# Out:
# Loss for the test dataset = 4.466
# Mean Absolute Error for the test dataset = 1.662

# %%
predictions = model.predict(test_generator)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step

# %%
#predictions.squeeze()

# %%
true = test_generator.labels

# %%
eval_df = pd.DataFrame({
    'actual': true,
    'predicted': predictions.squeeze()
})

# %%
eval_df['error'] = eval_df.predicted - eval_df.actual
eval_df['error_abs'] = abs(eval_df.error)

# %%
import seaborn as sns

# %%
sns.jointplot(x='actual',
              y='error',
              data=eval_df,
              kind='scatter',
              )
plt.xlabel('Actual Count', fontsize=13)
plt.ylabel('Error', fontsize=14)
plt.grid(':', alpha=.4)
plt.title('Actual Count vs Error', y=1.2, fontsize=14)
# Out:
# Text(0.5, 1.2, 'Actual Count vs Error')

# %% [markdown]
# ## Demo

# %%
img_id = df.id.iloc[0]
label = df['count'].iloc[0]
img_path = get_img_path(img_id, imgs_folder)

# %%
example_img = load_img(img_path)

# %%
plt.imshow(example_img)
plt.title(f'Total People = {label}')
plt.axis('off')
plt.show()

# %%
preprocess_img = manual_img_preprocessing(img_path)
prediction_result = model.predict(preprocess_img)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 832ms/step

# %%
prediction_result
# Out:
# array([[33.591026]], dtype=float32)

# %%
final_result = int(round(prediction_result[0][0]))

# %%
plt.imshow(example_img)
plt.title(f'Model Predicted Total People = {final_result}', color = 'blue')
plt.axis('off')
plt.show()

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 6))
ax[0].imshow(example_img)
ax[0].set_title(f'Total People = {label}')
ax[0].set_axis_off()


ax[1].imshow(example_img)
ax[1].set_title(f'Model Predicted Total People = {final_result}', color = 'blue')
ax[1].set_axis_off()
